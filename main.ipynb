# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("./Earthquakes.csv")
df
# Out:
#      latitude  longitude  depth  mag  net
# 0    -20.0030   -70.8741   17.0  6.2   us
# 1    -19.9246   -70.6278   20.0  6.7   us
# 2     -5.5660   -80.8790    9.8  6.3   us
# 3    -14.0935   -76.2968   20.0  6.1   us
# 4     33.6793   131.8197   79.0  6.3   us
# ..        ...        ...    ...  ...  ...
# 214   -9.0200  -108.2460   10.0  6.1  pde
# 215   30.5980    67.4550   14.0  6.4  pde
# 216   30.6390    67.3510   15.0  6.4  pde
# 217   -3.4940   145.8670   18.3  6.0  pde
# 218   -2.6350   145.5740   10.0  6.3  pde
#
# [219 rows x 5 columns]

# %%
print(f"first 6 rows\n {df.head()}")
print(f"\n\n COLUMNS \n {df.columns}")
print(f"\n\n VALUES \n {df.values}")
# Out:
# first 6 rows
#     latitude  longitude  depth  mag net
# 0  -20.0030   -70.8741   17.0  6.2  us
# 1  -19.9246   -70.6278   20.0  6.7  us
# 2   -5.5660   -80.8790    9.8  6.3  us
# 3  -14.0935   -76.2968   20.0  6.1  us
# 4   33.6793   131.8197   79.0  6.3  us
#
#
#  COLUMNS
#  Index(['latitude', 'longitude', 'depth', 'mag', 'net'], dtype='object')
#
#
#  VALUES
#  [[-20.003 -70.8741 17.0 6.2 'us']
#  [-19.9246 -70.6278 20.0 6.7 'us']
#  [-5.566 -80.879 9.8 6.3 'us']
#  ...
#  [30.639 67.351 15.0 6.4 'pde']
#  [-3.494 145.867 18.3 6.0 'pde']
#  [-2.635 145.574 10.0 6.3 'pde']]

# %%
sns.pairplot(df, hue='net')
plt.show()

# %%
data = df.values
x = data[:, 0:4]
y = data[:, 4]
data
# Out:
# array([[-20.003, -70.8741, 17.0, 6.2, 'us'],
#        [-19.9246, -70.6278, 20.0, 6.7, 'us'],
#        [-5.566, -80.879, 9.8, 6.3, 'us'],
#        ...,
#        [30.639, 67.351, 15.0, 6.4, 'pde'],
#        [-3.494, 145.867, 18.3, 6.0, 'pde'],
#        [-2.635, 145.574, 10.0, 6.3, 'pde']], dtype=object)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
sn = SVC()
sn.fit(x_train, y_train)

predict = sn.predict(x_test)
print(predict)
# Out:
# ['pde' 'pde' 'pde' 'pde' 'us' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde'
#  'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde'
#  'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'us' 'pde' 'pde' 'us'
#  'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde' 'pde']

# %%
model_acc = accuracy_score(y_test, predict)
print(model_acc)
# Out:
# 0.4090909090909091

# %%
x_new = np.array([[-60.8391, -19.9569, 10, 6.4]])
output = sn.predict(x_new)
print(f"the output is {output}")
# Out:
# the output is ['us']
